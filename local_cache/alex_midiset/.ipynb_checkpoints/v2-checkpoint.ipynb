# %%
import os
import pandas as pd
from glob2 import glob, iglob
from tqdm import tqdm
from music21.midi.translate import midiFilePathToStream
from multiprocessing import Pool
from timeout import timeout
import hashlib
import inspect
import pdb
import mido
# Out:
#
# Music21 v.4 is the last version that will support Python 2.
# Please start using Python 3 instead.
#
# Set music21.environment.UserSettings()['warnings'] = 0
# to disable this message.

# %% [markdown]
# ## Inside Label File
#  - Number of instruments
#  - Instrument names
#  - Original file name
#  - Length in seconds
#  - Number of midi events

# %%
batch = glob('v1/*.[mM][iI][dD]')
print('There are', len(batch), 'in folder.')
# Out:
# ('There are', 194416, 'in folder.')

# %%
out_midi_dir = 'v2/midis/'
out_label_dir = 'v2/labels/'

# %%
errors = []

def wrapper(tup):
    path, id_ = tup
    try:
        process(path, id_)
    except Exception as e:
        errors.append(e)

@timeout(50)
def process(path, id_):
    ##### CREATE NAMES
    f_name = os.path.split(path)[-1]
    hash_ = hashlib.md5(open(path, 'rb').read()).hexdigest()
    label_out = out_label_dir+hash_+'.csv'
    midi_out = out_midi_dir+hash_+'.mid'
    if os.path.exists(midi_out) and os.path.exists(label_out):
        # Return if already created
        return
    #### READ IN MIDIS AND GET INFO
    mid = mido.MidiFile(path)
    instruments = [x.name for x in mid.tracks]
    num_tracks = len(instruments)
    instruments = filter(lambda x: x != '', instruments)
    label = pd.DataFrame({'instruments': [','.join([x.replace(',', '\,') for x in instruments])],
                          'length': [mid.length],
                          'num_tracks': [num_tracks],
                          'num_nonempty_tracks': [len(instruments)],
                          'original_fname': [f_name],
                          'num_midi_events': [max([len(x) for x in mid.tracks])],
                          })
    label.to_csv(label_out, index=False)
    mid.save(midi_out)

# %%
# map(wrapper, tqdm(zip(batch, range(len(batch)))))
pool = Pool(7)
for i, _ in tqdm(enumerate(pool.imap_unordered(wrapper, zip(batch, range(len(batch)))))):
    pass
pool.close()
# pool.map(wrapper, tqdm(zip(batch, range(len(batch)))))
# Out:
# 28it [00:02,  9.92it/s]Process PoolWorker-6:
# Process PoolWorker-1:
# Process PoolWorker-3:
# Process PoolWorker-5:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process PoolWorker-2:
# Process PoolWorker-4:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process PoolWorker-7:
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
# Traceback (most recent call last):
#     self.run()
# Traceback (most recent call last):
#     self.run()
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 113, in worker
#     self._target(*self._args, **self._kwargs)
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 113, in worker
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 113, in worker
#     result = (True, func(*args, **kwds))
#     result = (True, func(*args, **kwds))
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-6-08324b3cbdb7>", line 6, in wrapper
#   File "<ipython-input-6-08324b3cbdb7>", line 6, in wrapper
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 113, in worker
#     process(path, id_)
#     result = (True, func(*args, **kwds))
#     process(path, id_)
#   File "<ipython-input-6-08324b3cbdb7>", line 6, in wrapper
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/timeout.py", line 97, in __call__
#     process(path, id_)
#     result = self.function(*args)
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/timeout.py", line 97, in __call__
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "<ipython-input-6-08324b3cbdb7>", line 26, in process
#     result = self.function(*args)
#     self.run()
#     'length': [mid.length],
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-6-08324b3cbdb7>", line 33, in process
#     mid.save(midi_out)
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/midifiles.py", line 351, in length
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 113, in worker
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/midifiles.py", line 416, in save
#     return sum(msg.time for msg in self)
#     self._target(*self._args, **self._kwargs)
#     self._save(file)
#     result = (True, func(*args, **kwds))
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/midifiles.py", line 351, in <genexpr>
#   File "<ipython-input-6-08324b3cbdb7>", line 6, in wrapper
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 113, in worker
#     return sum(msg.time for msg in self)
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/midifiles.py", line 429, in _save
#     process(path, id_)
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/midifiles.py", line 360, in __iter__
#     write_track(outfile, track)
#     result = (True, func(*args, **kwds))
#     for msg in merge_tracks(self.tracks):
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/timeout.py", line 97, in __call__
#   File "<ipython-input-6-08324b3cbdb7>", line 6, in wrapper
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/midifiles.py", line 257, in write_track
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/tracks.py", line 107, in merge_tracks
#     result = self.function(*args)
#     raw = msg.bytes()
#     return MidiTrack(fix_end_of_track(_to_reltime(messages)))
#   File "<ipython-input-6-08324b3cbdb7>", line 21, in process
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/messages/messages.py", line 182, in bytes
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/tracks.py", line 81, in fix_end_of_track
#     mid = mido.MidiFile(path)
#     return encode_message(vars(self))
#     for msg in messages:
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/midifiles.py", line 302, in __init__
# KeyboardInterrupt
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/tracks.py", line 69, in _to_reltime
#     self._load(file)
#     yield msg.copy(time=delta)
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/midifiles.py", line 337, in _load
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/messages/messages.py", line 109, in copy
#     self.tracks.append(read_track(infile, debug=self.debug))
#     check_msgdict(msgdict)
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/messages/checks.py", line 93, in check_msgdict
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/midifiles.py", line 217, in read_track
#     for name, value in msgdict.items():
#     msg = read_message(infile, status_byte, peek_data, delta)
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-6-08324b3cbdb7>", line 6, in wrapper
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/timeout.py", line 97, in __call__
#     process(path, id_)
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/timeout.py", line 97, in __call__
#     result = self.function(*args)
#   File "<ipython-input-6-08324b3cbdb7>", line 26, in process
#     result = self.function(*args)
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/midifiles.py", line 134, in read_message
#   File "<ipython-input-6-08324b3cbdb7>", line 26, in process
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     'length': [mid.length],
#     return Message.from_bytes([status_byte] + data_bytes, time=delta)
#     self._target(*self._args, **self._kwargs)
#     process(path, id_)
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/messages/messages.py", line 124, in from_bytes
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 113, in worker
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/midifiles.py", line 351, in length
#     result = (True, func(*args, **kwds))
#     vars(msg).update(msgdict)
#     return sum(msg.time for msg in self)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/midifiles.py", line 351, in <genexpr>
#     return sum(msg.time for msg in self)
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/midifiles.py", line 360, in __iter__
#     for msg in merge_tracks(self.tracks):
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/tracks.py", line 107, in merge_tracks
#     return MidiTrack(fix_end_of_track(_to_reltime(messages)))
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/tracks.py", line 81, in fix_end_of_track
#     for msg in messages:
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/timeout.py", line 97, in __call__
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/tracks.py", line 69, in _to_reltime
#   File "<ipython-input-6-08324b3cbdb7>", line 6, in wrapper
#     yield msg.copy(time=delta)
#     result = self.function(*args)
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/messages/messages.py", line 110, in copy
#     process(path, id_)
#     'length': [mid.length],
#     return self.__class__(**msgdict)
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/timeout.py", line 97, in __call__
#   File "<ipython-input-6-08324b3cbdb7>", line 26, in process
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/messages/messages.py", line 88, in __init__
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/midifiles.py", line 351, in length
#     result = self.function(*args)
#   File "<ipython-input-6-08324b3cbdb7>", line 21, in process
#     return sum(msg.time for msg in self)
#     mid = mido.MidiFile(path)
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/midifiles.py", line 302, in __init__
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/midifiles.py", line 351, in <genexpr>
#     return sum(msg.time for msg in self)
#     self._load(file)
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/midifiles.py", line 360, in __iter__
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/midifiles.py", line 337, in _load
#     check_msgdict(msgdict)
#     for msg in merge_tracks(self.tracks):
#     self.tracks.append(read_track(infile, debug=self.debug))
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/midifiles.py", line 217, in read_track
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/tracks.py", line 103, in merge_tracks
#     messages.extend(_to_abstime(track))
#     msg = read_message(infile, status_byte, peek_data, delta)
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/tracks.py", line 61, in _to_abstime
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/midifiles.py", line 134, in read_message
#     yield msg.copy(time=now)
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/messages/messages.py", line 109, in copy
#     check_msgdict(msgdict)
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/messages/checks.py", line 93, in check_msgdict
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/messages/checks.py", line 98, in check_msgdict
#     for name, value in msgdict.items():
#     check_value(name, value)
#     'length': [mid.length],
#     return Message.from_bytes([status_byte] + data_bytes, time=delta)
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/midifiles.py", line 351, in length
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/messages/messages.py", line 124, in from_bytes
#     return sum(msg.time for msg in self)
#     vars(msg).update(msgdict)
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/midifiles.py", line 351, in <genexpr>
# KeyboardInterrupt
#     return sum(msg.time for msg in self)
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/midifiles/midifiles.py", line 368, in __iter__
#     yield msg.copy(time=delta)
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/messages/messages.py", line 109, in copy
#     check_msgdict(msgdict)
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/messages/checks.py", line 85, in check_value
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/messages/checks.py", line 98, in check_msgdict
#     _CHECKS[name](value)
#     check_value(name, value)
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/messages/checks.py", line 85, in check_value
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/mido/messages/checks.py", line 54, in check_data_byte
#     if not isinstance(value, Integral):
#     _CHECKS[name](value)
# KeyboardInterrupt
#   File "/home/localhost/Desktop/Projects/Working/Autism/venv/lib/python2.7/abc.py", line 132, in __instancecheck__
# KeyboardInterrupt
#     if subclass is not None and subclass in cls._abc_cache:
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-8e687a90da56> in <module>()
#       1 # map(wrapper, tqdm(zip(batch, range(len(batch)))))
#       2 pool = Pool(7)
# ----> 3 for i, _ in tqdm(enumerate(pool.imap_unordered(wrapper, zip(batch, range(len(batch)))))):
#       4     pass
#       5 # pool.map(wrapper, tqdm(zip(batch, range(len(batch)))))
#
# /home/localhost/Desktop/Projects/Working/Autism/venv/local/lib/python2.7/site-packages/tqdm/_tqdm.pyc in __iter__(self)
#     953 """, fp_write=getattr(self.fp, 'write', sys.stderr.write))
#     954
# --> 955             for obj in iterable:
#     956                 yield obj
#     957                 # Update and possibly print the progressbar.
#
# /usr/lib/python2.7/multiprocessing/pool.pyc in next(self, timeout)
#     653                 if self._index == self._length:
#     654                     raise StopIteration
# --> 655                 self._cond.wait(timeout)
#     656                 try:
#     657                     item = self._items.popleft()
#
# /usr/lib/python2.7/threading.pyc in wait(self, timeout)
#     338         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     339             if timeout is None:
# --> 340                 waiter.acquire()
#     341                 if __debug__:
#     342                     self._note("%s.wait(): got it", self)
#
# KeyboardInterrupt:
